# %%
#1
def reverse(a: str) -> int:
    try:
        with open(a,'r') as f:
            a=f.read()
        return int(a[::-1] if a[0] != '-' else a[0]+a[:0:-1])
    except:
        with open(a,'w') as f:
            f.write("")
        a="File Ko Tồn Tại"
        return a
a=input()
print(reverse(a))

# %%
#2
def canWinNim (a: str):
    try:
        with open(a,'r') as f:
            a=f.read()
        a=int(a)
        if a%4==0:
            return False
        else:
            return True
    except:
        with open(a,'w') as f:
            f.write("")
        return False
a=input()
if canWinNim(a):
    print("win r do")
else:
    print("het cuu")

# %%
#3
def housesOfHogwarts(path: str):
    try:
        a=[]
        with open(path,'r') as f:
            a1=f.readline().strip()
            for i in range(int(a1)):
                a.append(f.readline())
        for i in a:
            print(i, end="")
    except:
        with open(path, 'w') as f:
            f.write("")
        print("loi doc file")
a=input()
housesOfHogwarts(a)

# %%
#4
import unicodedata

def xuly_chuoi(s):
    s = s.lower()
    s = unicodedata.normalize('NFD', s)
    s = ''.join(c for c in s if unicodedata.category(c) != 'Mn')
    s = s.replace('đ', 'd')
    return s

def lm(a,b):
    s,s1="",""
    try:
        with open(a,'r') as f:
            s=f.read()
        with open(b,'r') as f:
            s1=f.read()   
    except:
        return "loi doc file"
    s=xuly_chuoi(s)
    s1=xuly_chuoi(s1)
    b,b1={},{}
    for i in s:
        if i!=' ':
            b[i] = b.get(i,0) + 1
    for i in s1:
        if i!=' ':
            b1[i] = b1.get(i,0) + 1
    return b1==b
a=input()
b=input()
print(lm(a,b))

# %%
#5
def lm(a,b):
    s=""
    try:
        with open(a,'r') as f:
            s=f.read()
    except:
        return "loi doc file"
    kq=0
    for i in s:
        if i == b:
            kq+=1
    return kq
a=input()
b=input()
print(lm(a,b))

# %%
#6
def lm(a,b):
    s=""
    try:
        with open(a,'r') as f:
            s=f.read()
    except:
        return "loi doc file"
    kq=0
    for i in s:
        if i.lower() == b.lower():
            kq+=1
    return kq
a=input()
b=input()
print(lm(a,b))

# %%
#7
a=input()
try:
    with open(a,'r') as f:
        f.read()
    print("YES")
except:
    print("No")

# %%
#8
def lm(n):
    f=[""]*(n+1)
    f[0]="a"
    f[1]="b"
    for i in range(2,n):
        f[i]=f[i-1]+f[i-2]
    with open("output.txt",'w') as f1:
        for i in range(n):
            f1.write(f"f({i+1}) = {f[i]}\n")
a=int(input())
lm(a)

# %%
#9
def lm(a):
    b=[]
    try:
        c=[]
        with open(a,'r') as f:
            c=f.read().split('\n')
        for i in c:
            b.append(i.split(","))
    except:
        print("loi doc file")
    for i in b:
        if i[5]=="10":
            print(i[1]+" "+i[2])
a=input()
lm(a)

# %%
#10
def lm(a):
    b=[]
    try:
        with open(a,'r') as f:
            b=list(map(int,f.read().split()))
    except:
        print("loi doc file")
    d=[0]*(len(b))
    for i in range(len(b)):
        d[i]=b[i]
        for j in range(0,i-1):
            d[i]=max(d[i],d[j]+b[i])
    print(max(d))
a=input()
lm(a)

# %%
#11
def lm(a):
    b=[]
    try:
        with open(a,'r') as f:
            b=f.read().split()
        c=[int(i) for i in b]
        if len(c)==0:
            print("file rong")
        else:
            ln=c[0]
            nn=c[0]
            for i in c:
                ln=max(ln,i)
                nn=min(nn,i)
            print(ln,nn)
    except:
        print("Mission failed")
        return 
    
a=input()
lm(a)

# %%
#12
def lm(a):
    try:
        with open(a,'r') as f:
            b=f.read().split()
        c=[int(i) for i in b]
        c.sort()
        return max(c[0]*c[1]*c[len(c)-1],c[len(c)-1]*c[len(c)-2]*c[len(c)-3])
    except:
        print("Mission failed")
        return 
    
a=input()
lm(a)

# %%
#13
def lm(a):
    try:
        with open(a,'r') as f:
            n=f.readline().strip()
            b=f.readline().strip().split()
        c=[int(i) for i in b]
        s0=[ i for i in c  if i==0 ]
        s1=[ i for i in c  if i!=0 ]
        c=s1+s0
        print(*c)
    except:
        print("Mission failed")
        return 
    
a=input()
lm(a)

# %%
#14
import csv
def lm(a):
    try:
        with open(a, 'r') as f:
            b = csv.reader(f)
            next(b)
            c = []
            for i in b:
                if i: 
                    c.append(float(i[1]))
            if not c:
                return 0.0
            kq = sum(c) / len(c)
            return round(kq, 2) 
    except Exception:
        print("Mission failed")
        return 0.0
    
a=input()
lm(a)

# %%
#15
import csv

def lm(a):
    kq=[]
    try:
        with open(a, 'r') as f:
            b = csv.reader(f)
            next(b)
            for i in b:
                if len(i) < 4:
                    continue
                t = i[1].strip()
                cx = i[2].strip()
                d = float(i[3].strip())
                
                if d >= 8.0 and cx.lower() != "boring":
                    kq.append(t)
                    
        # Kiểm tra nếu danh sách rỗng
        if not kq:
            print( "All are boring!")
            return 
        print(*kq, sep="\n")
        return

    except (FileNotFoundError, IOError):
        print("Mission failed")
        return
a=input()
lm(a)

# %%
#16
def lm(a):
    try:
        with open(a, 'r') as f:
            b = [i.strip() for i in f.readlines() if i.strip()]
            
        for i in range(0, len(b), 2):
            loai_hinh = b[i].upper()
            thong_so = b[i+1].upper()
            chu_vi = 0.0
            if "SQUARE" in loai_hinh:
                side = float(thong_so.split("SIDE:")[1].strip())
                chu_vi = 4 * side
            elif "RECTANGLE" in loai_hinh:
                parts = thong_so.split()
                w = float(parts[1]) 
                h = float(parts[3]) 
                chu_vi = 2 * (w + h)
            elif "CIRCLE" in loai_hinh:
                r = float(thong_so.split("RADIUS:")[1].strip())
                chu_vi = 2 *3.1415* r
            print(f"{chu_vi:.2f}")
    except FileNotFoundError:
        print("Mission failed: Không tìm thấy tệp.")
    except Exception as e:
        print(f"Mission failed: {e}")

a=input()
lm(a)

# %%
#17
def lm(a):
    try:
        with open(a,'r') as f:
            f.readline()
            b=f.read().split()
        c=[int(i) for i in b]
        t=[1]*(len(c)+1)
        f=[1]*(len(c)+1)
        for i in range(len(c)-1,-1,-1):
            t[i]=c[i]*t[i+1]
        kq=[1]*(len(c))
        for i in range(len(c)):
            f[i]=c[i]* ( f[i-1] if i>0 else 1 )
            kq[i]=t[i+1]*(f[i-1] if i>0 else 1)
        print(*kq)
    except:
        print("loi doc file")
a=input()
lm(a)

# %%
#18
def lm(a):
    try:
        with open(a, 'r') as f:
            c = [i.strip().upper() for i in f.readlines() if i.strip()]
            x1, y1 = 0.0, 0.0
            x2, y2 = 0.0, 0.0
            v = 0.0
            
            for i in c:
                b = i.split()
                if "SRC" in i:
                    x1 = float(b[2])
                    y1 = float(b[4])
                elif "DES" in i:
                    x2 = float(b[2])
                    y2 = float(b[4])
                elif "VELOCITY" in i:
                    v = float(b[1])
            
            if v == 0:
                return 0.0
            s=((x2-x1)**2+(y2-y1)**2)**0.5
            t=s/v
            return round(t,2)
            
    except Exception:
        print("Mission failed")
        return 0.0
a=input()
print(lm(a))

# %%
#19
import struct
def lm(a):
    try:
        with open(a, 'rb') as f:
            while True:
                b = f.read(8) 
                if not b:
                    break
                if len(b) == 8:
                    so_thuc = struct.unpack('d', b)[0]
                    print(f"{so_thuc:.5f}")
                    
    except:
        print("Mission failed")
a=input()
lm(a)

# %%
#20
def lm(path_file):
    try:
        with open(path_file, 'r') as f:
            data = [line.split() for line in f if line.strip()]
        if not data:
            return
        n = len(data)
        m = [[int(x) for x in row] for row in data]
        kq = [[0] * n for _ in range(n)]
        for r in range(n):
            for c in range(n):
                tong = 0
                so_luong = 0
                for i in range(r - 1, r + 2):
                    for j in range(c - 1, c + 2):
                        if 0 <= i < n and 0 <= j < n:
                            tong += m[i][j]
                            so_luong += 1
                kq[r][c]=tong //so_luong
        for i in kq:
            print(*i)
    except Exception:
        print("Mission failed")

a = input()
lm(a)
