# %% [markdown]
# bai 1

# %%
n=int(input())
sum=0
for i in range(n+1):
  sum+=i
print(sum)
# Out:
# 55

# %% [markdown]
# bai 2

# %%
n=float(input())
check=True
while n.is_integer()==False:
  n=float(input())
for i in range(2,int(n**0.5)+1):
  if n%i==0:
    check=False
print(check)
# Out:
# True

# %% [markdown]
# bai 3

# %%
n=int(input())
o=1
for i in range(1,n+1):
  o*=i
print(o)
# Out:
# 362880

# %% [markdown]
# bai 4

# %%
n=int(input())
n=abs(n)
x=0
while n>0:
  n//=10
  x+=1
print(x)
# Out:
# 3

# %% [markdown]
# bai 5

# %%
n=int(input())
lst=list(map(int,input().split()))
check="It's a joke!"
for i in lst:
    if i==42:
        check="I've found the meaning of life!"
print(check)
# Out:
# I've found the meaning of life!

# %% [markdown]
# bai 6

# %%
def kt(a):
    if a<2 : 
        return False
    for i in range(2,int(a**0.5)+1):
        if a%i==0:
            return False
    return True
a,b=map(int,input().split())
kq=0
while a<=b:
    kq+=a if kt(a) else 0
    a+=1
print(kq)
# Out:
# 17

# %% [markdown]
# bai 7

# %%
def kt1(a):
    if a<2 : 
        return False
    for i in range(2,int(a**0.5)+1):
        if a%i==0:
            return False
    return True
n=int(input())
if kt(n):
    print(n)
else:
    kq=2
    for i in range (2,int(n**0.5)+1):
        if n%i==0:
            if kt(i):
                kq=max(kq,i)
            if kt(a//i):
                kq=max(kq,a//i)
    print(kq)

# %% [markdown]
# bai 8

# %%
def kt(a):
    s=str(a)
    for i in range(0,(len(s)//2)):
        if(s[i]!=s[len(s)-1-i]):
            return False
    return True
def dao(a):
    kq=0
    while a>0:
        kq= kq*10+ a%10
        a=a//10
    return kq
b=0
n=int(input())
while kt(n)==False:
    n=n+dao(n)
    b+=1
print(b,n)

# %% [markdown]
# bai 9

# %%
n=int(input())
def kt(i):
    d=[]
    for j in range(0,10):
        d.append(0)
    i=str(i*i)
    for j in i:
        d[int(j)]+=1
        if d[int(j)]>1:
            return False
    return True
i=1
while(i*i<=n):
    if(kt(i)):
        print(i*i,end=" ")
    i+=1

# %% [markdown]
# bai 10

# %%
def dem(n):
    sl=1
    while n>1:
        if n%2==0:
            n=n//2
        else :
            n=n*3+1
        sl+=1
    return sl
n=int(input())
a=[]
for i in range(0,n+1):
    a.append(0) 
k=0
for i in range(1,n+1):
    a[i]=dem(i)
    if a[i]>a[k]:
        k=i
print(k,a[k])

# %% [markdown]
# bai 11

# %%
n=int(input())
kq=0
for i in range(1,int(n**0.5)+1):
    if n%i==0:
        if i%2==0:
            kq+=1
        if i!=n//i and (n//i)%2==0:
            kq+=1
print(kq)

# %% [markdown]
# bai 12

# %%
a=1.007
n,b=map(float,input().split())
while b>0:
    n=n*a
    b-=1
print(int(n))

# %% [markdown]
# bai 13

# %%
def t(a):
    kq=1
    for i in range (2,int(a**0.5)+1):
        if a%i==0:
            kq+=i
            if (a//i)!=i:
                kq+=(a//i)
    return kq
a,b=map(int,input().split())
if t(a)==b and t(b)==a:
    print("true")
else:
    print("false")

# %%
bai 14

# %%
def t(a,b):
    kq=1
    for i in range (1,int(a**0.5)+1):
        if a%i==0:
            if b%i==0:
                kq=max(kq,i)
            if b%(a//i)==0:
                kq=max((a//i),kq)
    return kq
a,b = map(int,input().split())
print(t(a,b))

# %% [markdown]
# bai 15

# %%
a,b = map(int,input().split())
i,j=1,1
while i*2+j*4 != b :
    i+=1;
    j=a-i
    if a>i :
        break
if i*2+j*4 == b:
    print(i,j)
else :
    print("invalid")

# %% [markdown]
# bai 16

# %%
a=3
while a<97:
    a+=3
    if a%2==0:
        print(a, end=" ")

# %% [markdown]
# bai 17

# %%
a= int (input())
for i in range(1,11):
    print(a,"*",i,"=",a*i)

# %% [markdown]
# bai 18

# %%
def t(a,b):
    kq=1
    for i in range (1,int(a**0.5)+1):
        if a%i==0:
            if b%i==0:
                print(i,end=" ")
            if b%(a//i)==0:
                print(a//i,end=" ")
a,b = map(int,input().split())
t(a,b)

# %% [markdown]
# bai 19

# %%
n=int(input())
i=2
while i<=n:
    print(i,end=" ")
    i+=2

# %% [markdown]
# bai 20

# %%
n=int(input())
while n>1:
    if n%2!=0:
        break
    else : n=n//2
if n==1 :
    print("True")
else:
    print("False")

# %% [markdown]
# bai 21

# %%
n=int(input())
n=list(str(n))
k=0
for i in range(len(n)):
    k+=int(n[i])
print(k)

# %% [markdown]
# bai 22

# %%
n=input()
c,l=0,0
for i in n:
    if int(i)%2==0:
        c+=1
    else: 
        l+=1
print("chan :",c)
print("le :",l)

# %% [markdown]
# bai 23

# %%
n=int(input())
s=0
i=1
while s<n:
    s+=i
    i+=1
print(i-2)

# %% [markdown]
# bai 24

# %%
n=int(input())
s=0
i=1
while s<n:
    s+=1/i
    i+=1
print(i-1)

# %% [markdown]
# bai 25

# %%
a=int(input())
if a!=-1:
    ln,nn=a,a
else:
    ln,nn=0,0
while a!=-1:
    a=int(input())
    if a==-1:
        break
    ln=max(ln,a)
    nn=min(nn,a)
print("nho nhat :",nn)
print("lon nhat :",ln)

# %% [markdown]
# bai 26

# %%
a,b=1,1
n=int(input())
while b<n:
    a,b=b,a+b
print(a)

# %% [markdown]
# bai 27

# %%
def kt(i,j):
    if i == j-1: return False
    while i<=j:
        if 'a'<= s[i] <= 'z' or 'A'<= s[i]<='Z' or s[i]==' ':
            i+=1
        else :
            return False
        
    return True

s=input()
s=' '+s+' '
i,j=0,1
kq=0
n=0
for g in s:
    n+=1
while i < n and j < n:
    if s[j]==' ':
        if kt(i,j) :
            kq+=1
            
        i=j
    j+=1
print(kq)

# %% [markdown]
# bai 28

# %%
def kt(i,j):
    if i == j-1: return False
    while i<=j:
        if 'a'<= s[i] <= 'z' or 'A'<= s[i]<='Z' or s[i]==' ':
            i+=1
        else :
            return False
        
    return True
def iny(i,j):
    i=i+1
    while i <j:
        print(s[i],end="")
        i+=1

s=input()
s=' '+s+' '
i,j=0,1
n=0
for g in s:
    n+=1
while i < n and j < n:
    if s[j]==' ':
        if kt(i,j) :
            iny(i,j)
            break
        i=j
    j+=1

# %% [markdown]
# bai 29

# %%
s=input().split(",")
kq=0
for i in s:
    kq+=int(i)
print(kq)

# %% [markdown]
# bai 30

# %%
s=input()
h,th,c=0,0,0
for i in s:
    if 'a'<= i <= 'z' :
        th+=1
    elif 'A'<= i<='Z' :
        h +=1
    elif  '0'<=i<='9':
        c+=1
print("ky tu hoa :",h)
print("ky tu thuong :",th)
print("ky tu so :",c)

# %% [markdown]
# bai 31

# %%
s=input()
kq=0
for i in s:
    if '0'<=i <='9':
        kq+=int(i)
print(kq)

# %% [markdown]
# bai 32

# %%
def kt1(s):
    for i in s:
        if 'a'<= i <= 'z' or 'A'<= i<='Z' or '0'<=i<='9':
            continue
        else: return True
    return False
def kt2(s):
    for i in s:
        if 'a'<= i <= 'z':
            return True
    return False
def kt3(s):
    for i in s:
        if 'A'<= i<='Z':
            return True
    return False
def kt4(s):
    for i in s:
        if '0'<= i<='9':
            return True
    return False
def kt(s):
    if len(s)<6:
        return False
    if kt1(s) and kt2(s) and kt3(s) and kt4(s):
        return True
    return False
s=input()
if kt(s):
    print("manh")
else:
    print("yeu")

# %% [markdown]
# bai 33

# %%
s=input()
s2=''
i=len(s)-1
j=0
while i>=0:
    s2=s[i]+s2
    j+=1
    if j==3 and i !=0:
        s2='.'+s2
        j=0
    i-=1
print(s2)

# %% [markdown]
# bai 34

# %%
a=input()
b=input()
t=a.find(b)
if t!=-1:
    a=a[:t]+ a[t+len(b):]
print(a)
